# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
filenames[0:5]
# Out:
# ['data\\1001349.yaml',
#  'data\\1001351.yaml',
#  'data\\1001353.yaml',
#  'data\\1004729.yaml',
#  'data\\1007655.yaml']

# %%
final_df = pd.DataFrame()  # create blank data frame
counter = 1
for file in tqdm (filenames):
    with open(file,'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id']= counter
        final_df = final_df.append(df)
        counter+=1
final_df
# Out:
#   0%|          | 0/1433 [00:00<?, ?it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|          | 1/1433 [00:02<1:08:20,  2.86s/it]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|          | 2/1433 [00:03<32:16,  1.35s/it]  C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|          | 3/1433 [00:04<37:24,  1.57s/it]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|          | 4/1433 [00:05<26:35,  1.12s/it]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|          | 5/1433 [00:05<19:38,  1.21it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|          | 6/1433 [00:05<14:52,  1.60it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|          | 7/1433 [00:06<12:20,  1.93it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|          | 8/1433 [00:08<23:12,  1.02it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|          | 9/1433 [00:08<18:36,  1.28it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|          | 10/1433 [00:08<15:57,  1.49it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|          | 11/1433 [00:10<24:31,  1.03s/it]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|          | 12/1433 [00:11<19:12,  1.23it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|          | 13/1433 [00:11<15:45,  1.50it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|          | 14/1433 [00:11<13:01,  1.82it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|          | 15/1433 [00:13<21:24,  1.10it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|          | 16/1433 [00:13<17:34,  1.34it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|          | 17/1433 [00:14<14:45,  1.60it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|▏         | 18/1433 [00:14<12:47,  1.84it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|▏         | 19/1433 [00:15<12:31,  1.88it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|▏         | 20/1433 [00:15<11:54,  1.98it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   1%|▏         | 21/1433 [00:16<13:29,  1.74it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 22/1433 [00:16<12:00,  1.96it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 23/1433 [00:16<09:45,  2.41it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 24/1433 [00:17<09:19,  2.52it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 25/1433 [00:17<10:26,  2.25it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 26/1433 [00:18<10:21,  2.26it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 27/1433 [00:18<08:48,  2.66it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 28/1433 [00:18<08:12,  2.85it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 29/1433 [00:19<09:08,  2.56it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 30/1433 [00:19<08:36,  2.72it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 31/1433 [00:19<07:56,  2.94it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 32/1433 [00:20<07:55,  2.95it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 33/1433 [00:20<07:25,  3.14it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 34/1433 [00:21<10:17,  2.27it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   2%|▏         | 35/1433 [00:21<09:05,  2.56it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 36/1433 [00:22<11:28,  2.03it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 37/1433 [00:22<09:47,  2.38it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 38/1433 [00:22<09:03,  2.57it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 39/1433 [00:23<10:43,  2.17it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 40/1433 [00:23<10:00,  2.32it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 41/1433 [00:23<09:23,  2.47it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 42/1433 [00:24<09:10,  2.53it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 43/1433 [00:24<09:22,  2.47it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 44/1433 [00:25<08:41,  2.66it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 45/1433 [00:25<10:29,  2.21it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 46/1433 [00:26<09:45,  2.37it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 47/1433 [00:26<08:55,  2.59it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 48/1433 [00:26<08:35,  2.69it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 49/1433 [00:27<09:41,  2.38it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   3%|▎         | 50/1433 [00:27<10:34,  2.18it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▎         | 51/1433 [00:28<11:50,  1.95it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▎         | 52/1433 [00:28<10:29,  2.19it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▎         | 53/1433 [00:29<12:06,  1.90it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▍         | 54/1433 [00:30<12:22,  1.86it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▍         | 55/1433 [00:30<13:09,  1.75it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▍         | 56/1433 [00:30<11:19,  2.03it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▍         | 57/1433 [00:31<10:18,  2.22it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▍         | 58/1433 [00:31<09:07,  2.51it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▍         | 59/1433 [00:31<08:10,  2.80it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▍         | 60/1433 [00:32<08:59,  2.55it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▍         | 61/1433 [00:32<09:29,  2.41it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▍         | 62/1433 [00:33<10:35,  2.16it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▍         | 63/1433 [00:33<10:58,  2.08it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   4%|▍         | 64/1433 [00:34<10:45,  2.12it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▍         | 65/1433 [00:34<10:48,  2.11it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▍         | 66/1433 [00:35<09:08,  2.49it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▍         | 67/1433 [00:35<08:56,  2.55it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▍         | 68/1433 [00:35<08:00,  2.84it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▍         | 69/1433 [00:35<07:36,  2.99it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▍         | 70/1433 [00:36<07:40,  2.96it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▍         | 71/1433 [00:36<07:34,  2.99it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▌         | 72/1433 [00:37<08:45,  2.59it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▌         | 73/1433 [00:37<09:55,  2.28it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▌         | 74/1433 [00:38<09:15,  2.45it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▌         | 75/1433 [00:38<08:29,  2.66it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▌         | 76/1433 [00:38<09:41,  2.33it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▌         | 77/1433 [00:39<12:39,  1.79it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   5%|▌         | 78/1433 [00:40<13:47,  1.64it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▌         | 79/1433 [00:40<12:24,  1.82it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▌         | 80/1433 [00:41<12:17,  1.83it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▌         | 81/1433 [00:41<12:13,  1.84it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▌         | 82/1433 [00:42<12:17,  1.83it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▌         | 83/1433 [00:42<10:50,  2.08it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▌         | 84/1433 [00:43<11:44,  1.92it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▌         | 85/1433 [00:44<11:59,  1.87it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▌         | 86/1433 [00:44<10:14,  2.19it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▌         | 87/1433 [00:44<10:24,  2.16it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▌         | 88/1433 [00:45<09:24,  2.38it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▌         | 89/1433 [00:45<09:22,  2.39it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▋         | 90/1433 [00:46<09:40,  2.31it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▋         | 91/1433 [00:46<09:07,  2.45it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▋         | 92/1433 [00:46<08:30,  2.63it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   6%|▋         | 93/1433 [00:47<11:25,  1.95it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 94/1433 [00:47<09:34,  2.33it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 95/1433 [00:48<08:48,  2.53it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 96/1433 [00:48<08:35,  2.60it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 97/1433 [00:48<08:32,  2.61it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 98/1433 [00:49<09:13,  2.41it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 99/1433 [00:49<09:43,  2.29it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 100/1433 [00:50<09:54,  2.24it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 101/1433 [00:50<09:12,  2.41it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 102/1433 [00:51<09:19,  2.38it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 103/1433 [00:51<08:24,  2.64it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 104/1433 [00:51<08:38,  2.56it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 105/1433 [00:52<09:07,  2.42it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 106/1433 [00:52<09:07,  2.43it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   7%|▋         | 107/1433 [00:53<10:19,  2.14it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 108/1433 [00:53<09:49,  2.25it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 109/1433 [00:54<10:26,  2.11it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 110/1433 [00:54<10:14,  2.15it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 111/1433 [00:55<10:37,  2.07it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 112/1433 [00:55<10:51,  2.03it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 113/1433 [00:55<09:33,  2.30it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 114/1433 [00:56<09:34,  2.30it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 115/1433 [00:56<08:34,  2.56it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 116/1433 [00:56<08:11,  2.68it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 117/1433 [00:58<16:07,  1.36it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 118/1433 [00:58<13:10,  1.66it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 119/1433 [00:59<10:58,  2.00it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 120/1433 [00:59<10:09,  2.16it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   8%|▊         | 121/1433 [00:59<08:39,  2.52it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▊         | 122/1433 [00:59<07:34,  2.88it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▊         | 123/1433 [01:00<09:59,  2.19it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▊         | 124/1433 [01:00<08:39,  2.52it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▊         | 125/1433 [01:01<07:21,  2.96it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▉         | 126/1433 [01:01<08:19,  2.62it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▉         | 127/1433 [01:01<08:29,  2.57it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▉         | 128/1433 [01:02<08:51,  2.45it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▉         | 129/1433 [01:02<08:39,  2.51it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▉         | 130/1433 [01:03<08:22,  2.60it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▉         | 131/1433 [01:03<08:00,  2.71it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▉         | 132/1433 [01:03<07:14,  2.99it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▉         | 133/1433 [01:04<07:14,  2.99it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▉         | 134/1433 [01:04<06:40,  3.24it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▉         | 135/1433 [01:04<06:18,  3.43it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   9%|▉         | 136/1433 [01:04<06:40,  3.24it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|▉         | 137/1433 [01:05<06:42,  3.22it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|▉         | 138/1433 [01:05<08:10,  2.64it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|▉         | 139/1433 [01:06<07:19,  2.95it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|▉         | 140/1433 [01:06<07:41,  2.80it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|▉         | 141/1433 [01:06<08:41,  2.48it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|▉         | 142/1433 [01:07<07:28,  2.88it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|▉         | 143/1433 [01:07<07:15,  2.96it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|█         | 144/1433 [01:07<06:40,  3.22it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|█         | 145/1433 [01:07<06:19,  3.39it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|█         | 146/1433 [01:08<06:07,  3.50it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|█         | 147/1433 [01:08<06:31,  3.28it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|█         | 148/1433 [01:09<07:14,  2.96it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|█         | 149/1433 [01:09<06:33,  3.26it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  10%|█         | 150/1433 [01:09<06:12,  3.44it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█         | 151/1433 [01:09<07:26,  2.87it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█         | 152/1433 [01:10<07:52,  2.71it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█         | 153/1433 [01:10<08:42,  2.45it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█         | 154/1433 [01:11<08:18,  2.56it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█         | 155/1433 [01:11<07:26,  2.86it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█         | 156/1433 [01:11<07:19,  2.91it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█         | 157/1433 [01:12<08:05,  2.63it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█         | 158/1433 [01:12<10:00,  2.12it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█         | 159/1433 [01:13<08:46,  2.42it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█         | 160/1433 [01:13<09:09,  2.32it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█         | 161/1433 [01:14<09:10,  2.31it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█▏        | 162/1433 [01:14<08:27,  2.50it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█▏        | 163/1433 [01:14<07:55,  2.67it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  11%|█▏        | 164/1433 [01:15<09:34,  2.21it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  12%|█▏        | 165/1433 [01:15<09:20,  2.26it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  12%|█▏        | 166/1433 [01:16<09:23,  2.25it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  12%|█▏        | 167/1433 [01:16<08:08,  2.59it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  12%|█▏        | 168/1433 [01:17<08:57,  2.35it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  12%|█▏        | 169/1433 [01:17<09:15,  2.27it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...
#   final_df = final_df.append(df)
#  96%|█████████▋| 1380/1433 [08:31<00:16,  3.29it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  96%|█████████▋| 1381/1433 [08:31<00:15,  3.27it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  96%|█████████▋| 1382/1433 [08:32<00:14,  3.49it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1383/1433 [08:32<00:17,  2.86it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1384/1433 [08:32<00:16,  3.05it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1385/1433 [08:33<00:14,  3.26it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1386/1433 [08:33<00:13,  3.42it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1387/1433 [08:33<00:12,  3.54it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1388/1433 [08:33<00:12,  3.73it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1389/1433 [08:34<00:11,  3.90it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1390/1433 [08:34<00:11,  3.76it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1391/1433 [08:34<00:12,  3.43it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1392/1433 [08:34<00:11,  3.54it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1393/1433 [08:35<00:10,  3.64it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1394/1433 [08:35<00:13,  2.92it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1395/1433 [08:35<00:12,  3.10it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1396/1433 [08:36<00:09,  3.80it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  97%|█████████▋| 1397/1433 [08:36<00:09,  3.76it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1398/1433 [08:36<00:09,  3.72it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1399/1433 [08:36<00:08,  3.78it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1400/1433 [08:37<00:07,  4.32it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1401/1433 [08:37<00:07,  4.16it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1402/1433 [08:37<00:07,  4.12it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1403/1433 [08:37<00:07,  4.05it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1404/1433 [08:38<00:07,  4.04it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1405/1433 [08:38<00:07,  3.90it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1406/1433 [08:38<00:08,  3.11it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1407/1433 [08:39<00:07,  3.28it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1408/1433 [08:39<00:06,  3.94it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1409/1433 [08:39<00:06,  3.96it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1410/1433 [08:39<00:05,  3.90it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  98%|█████████▊| 1411/1433 [08:39<00:05,  4.17it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▊| 1412/1433 [08:40<00:05,  3.95it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▊| 1413/1433 [08:40<00:05,  3.90it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▊| 1414/1433 [08:40<00:04,  3.92it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▊| 1415/1433 [08:41<00:04,  3.80it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▉| 1416/1433 [08:41<00:04,  3.86it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▉| 1417/1433 [08:41<00:04,  3.75it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▉| 1418/1433 [08:42<00:05,  2.72it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▉| 1419/1433 [08:42<00:04,  2.88it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▉| 1420/1433 [08:42<00:04,  2.94it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▉| 1421/1433 [08:43<00:03,  3.04it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▉| 1422/1433 [08:43<00:03,  3.21it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▉| 1423/1433 [08:43<00:03,  3.10it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▉| 1424/1433 [08:44<00:02,  3.19it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#  99%|█████████▉| 1425/1433 [08:44<00:02,  3.33it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# 100%|█████████▉| 1426/1433 [08:44<00:02,  3.40it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# 100%|█████████▉| 1427/1433 [08:44<00:01,  3.63it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# 100%|█████████▉| 1428/1433 [08:45<00:01,  3.59it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# 100%|█████████▉| 1429/1433 [08:45<00:01,  3.84it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# 100%|█████████▉| 1430/1433 [08:45<00:00,  3.05it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# 100%|█████████▉| 1431/1433 [08:46<00:00,  3.17it/s]C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2050048326.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# 100%|█████████▉| 1432/1433 [08:46<00:00,  2.72it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       3 for file in tqdm (filenames):
#       4     with open(file,'r') as f:
# ----> 5         df = pd.json_normalize(safe_load(f))
#       6         df['match_id']= counter
#       7         final_df = final_df.append(df)
#
# File ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py:443, in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     441     data = list(data)
#     442 else:
# --> 443     raise NotImplementedError
#     445 # check to see if a simple recursive function is possible to
#     446 # improve performance (see #15621) but only for cases such
#     447 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     448 if (
#     449     record_path is None
#     450     and meta is None
#    (...)
#     453     and max_level is None
#     454 ):
#
# NotImplementedError:

# %%
backup = final_df.copy() # not assign directly COPY in another file

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
#
#    meta.created  meta.revision    info.dates info.gender info.match_type  \
# 0    2017-02-18              2  [2017-02-17]        male             T20
# 0    2017-02-19              2  [2017-02-19]        male             T20
# 0    2017-02-23              1  [2017-02-22]        male             T20
# 0    2016-09-12              1  [2016-09-05]        male             T20
# 0    2016-06-19              1  [2016-06-18]        male             T20
# ..          ...            ...           ...         ...             ...
# 0    2016-03-05              2  [2016-03-04]        male             T20
# 0    2016-03-08              1  [2016-03-06]        male             T20
# 0    2016-02-03              1  [2016-02-03]        male             T20
# 0    2016-09-12              1  [2016-09-06]        male             T20
# 0    2016-09-12              1  [2016-09-09]        male             T20
#
#     info.outcome.by.wickets info.outcome.winner  info.overs  ...  \
# 0                       5.0           Sri Lanka          20  ...
# 0                       2.0           Sri Lanka          20  ...
# 0                       NaN           Australia          20  ...
# 0                       NaN           Hong Kong          20  ...
# 0                       NaN            Zimbabwe          20  ...
# ..                      ...                 ...         ...  ...
# 0                       6.0            Pakistan          20  ...
# 0                       8.0               India          20  ...
# 0                       NaN         Netherlands          20  ...
# 0                       NaN           Australia          20  ...
# 0                       4.0           Australia          20  ...
#
#    info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 0                   NaN                    NaN                NaN
# 0                   NaN                    NaN                NaN
# 0                  41.0                    NaN                NaN
# 0                  40.0                    NaN                NaN
# 0                   2.0                    NaN                NaN
# ..                  ...                    ...                ...
# 0                   NaN                    NaN                1.0
# 0                   NaN                    NaN                NaN
# 0                  84.0                    NaN                NaN
# 0                  85.0                    NaN                NaN
# 0                   NaN                    NaN                NaN
#
#    info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                  NaN                 NaN                     NaN
# 0                  NaN                 NaN                     NaN
# 0                  NaN                 NaN                     NaN
# 0                  NaN                 NaN                     NaN
# 0                  NaN                 NaN                     NaN
# ..                 ...                 ...                     ...
# 0                  NaN                 NaN                     NaN
# 0                  NaN                 NaN                     NaN
# 0                  NaN                 NaN                     NaN
# 0                  NaN                 NaN                     NaN
# 0                  NaN                 NaN                     NaN
#
#     info.supersubs.New Zealand info.supersubs.South Africa  info.bowl_out  \
# 0                          NaN                         NaN            NaN
# 0                          NaN                         NaN            NaN
# 0                          NaN                         NaN            NaN
# 0                          NaN                         NaN            NaN
# 0                          NaN                         NaN            NaN
# ..                         ...                         ...            ...
# 0                          NaN                         NaN            NaN
# 0                          NaN                         NaN            NaN
# 0                          NaN                         NaN            NaN
# 0                          NaN                         NaN            NaN
# 0                          NaN                         NaN            NaN
#
#     info.outcome.bowl_out
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
# ..                    ...
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
#
# [1432 rows x 28 columns]

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.wickets',
    'info.outcome.by.runs'
],inplace=True)

# %%
final_df
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#    info.gender info.match_type info.outcome.winner  info.overs  \
# 0         male             T20           Sri Lanka          20
# 0         male             T20           Sri Lanka          20
# 0         male             T20           Australia          20
# 0         male             T20           Hong Kong          20
# 0         male             T20            Zimbabwe          20
# ..         ...             ...                 ...         ...
# 0         male             T20            Pakistan          20
# 0         male             T20               India          20
# 0         male             T20         Netherlands          20
# 0         male             T20           Australia          20
# 0         male             T20           Australia          20
#
#    info.player_of_match                           info.teams  \
# 0       [DAS Gunaratne]               [Australia, Sri Lanka]
# 0       [DAS Gunaratne]               [Australia, Sri Lanka]
# 0             [A Zampa]               [Australia, Sri Lanka]
# 0                   NaN                 [Ireland, Hong Kong]
# 0        [E Chigumbura]                    [Zimbabwe, India]
# ..                  ...                                  ...
# 0          [Umar Akmal]                [Pakistan, Sri Lanka]
# 0            [S Dhawan]                  [Bangladesh, India]
# 0    [Mudassar Bukhari]  [United Arab Emirates, Netherlands]
# 0          [GJ Maxwell]               [Sri Lanka, Australia]
# 0          [GJ Maxwell]               [Sri Lanka, Australia]
#
#    info.toss.decision      info.toss.winner  \
# 0               field             Sri Lanka
# 0               field             Sri Lanka
# 0               field             Sri Lanka
# 0                 bat             Hong Kong
# 0               field                 India
# ..                ...                   ...
# 0               field              Pakistan
# 0               field                 India
# 0               field  United Arab Emirates
# 0               field             Sri Lanka
# 0                 bat             Sri Lanka
#
#                           info.umpires  \
# 0               [MD Martell, P Wilson]
# 0                [SD Fry, SJ Nogajski]
# 0               [MD Martell, P Wilson]
# 0                  [R Black, AJ Neill]
# 0             [TJ Matibiri, RB Tiffin]
# ..                                 ...
# 0         [AK Chaudhary, Enamul Haque]
# 0     [RSA Palliyaguruge, Shozab Raza]
# 0           [CK Nandan, Sarika Prasad]
# 0       [REJ Martinesz, RR Wimalasiri]
# 0   [REJ Martinesz, RSA Palliyaguruge]
#
#                                  info.venue  match_id    info.city
# 0                  Melbourne Cricket Ground         1          NaN
# 0            Simonds Stadium, South Geelong         2     Victoria
# 0                             Adelaide Oval         3          NaN
# 0         Bready Cricket Club, Magheramason         4  Londonderry
# 0                        Harare Sports Club         5          NaN
# ..                                      ...       ...          ...
# 0             Shere Bangla National Stadium      1428       Mirpur
# 0             Shere Bangla National Stadium      1429       Mirpur
# 0                               ICC Academy      1430        Dubai
# 0   Pallekele International Cricket Stadium      1431          NaN
# 0                       R Premadasa Stadium      1432      Colombo
#
# [1432 rows x 14 columns]

# %%
final_df['info.gender'].value_counts()
# Out:
# male      966
# female    466
# Name: info.gender, dtype: int64

# %%
final_df = final_df [final_df ['info.gender']=='male']
final_df.drop(columns =['info.gender'],inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3827630602.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns =['info.gender'],inplace=True)

# %%
final_df.head(5)
# Out:
#                                              innings    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0  [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
#
#   info.match_type info.outcome.winner  info.overs info.player_of_match  \
# 0             T20           Sri Lanka          20      [DAS Gunaratne]
# 0             T20           Sri Lanka          20      [DAS Gunaratne]
# 0             T20           Australia          20            [A Zampa]
# 0             T20           Hong Kong          20                  NaN
# 0             T20            Zimbabwe          20       [E Chigumbura]
#
#                info.teams info.toss.decision info.toss.winner  \
# 0  [Australia, Sri Lanka]              field        Sri Lanka
# 0  [Australia, Sri Lanka]              field        Sri Lanka
# 0  [Australia, Sri Lanka]              field        Sri Lanka
# 0    [Ireland, Hong Kong]                bat        Hong Kong
# 0       [Zimbabwe, India]              field            India
#
#                info.umpires                         info.venue  match_id  \
# 0    [MD Martell, P Wilson]           Melbourne Cricket Ground         1
# 0     [SD Fry, SJ Nogajski]     Simonds Stadium, South Geelong         2
# 0    [MD Martell, P Wilson]                      Adelaide Oval         3
# 0       [R Black, AJ Neill]  Bready Cricket Club, Magheramason         4
# 0  [TJ Matibiri, RB Tiffin]                 Harare Sports Club         5
#
#      info.city
# 0          NaN
# 0     Victoria
# 0          NaN
# 0  Londonderry
# 0          NaN

# %%
final_df ['info.match_type'].value_counts()
# Out:
# T20    966
# Name: info.match_type, dtype: int64

# %%
final_df = final_df[final_df['info.overs']== 20]
final_df.drop(columns = ['info.overs','info.match_type'],inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\2956149035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns = ['info.overs','info.match_type'],inplace=True)

# %%
final_df
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#    info.outcome.winner info.player_of_match  \
# 0            Sri Lanka      [DAS Gunaratne]
# 0            Sri Lanka      [DAS Gunaratne]
# 0            Australia            [A Zampa]
# 0            Hong Kong                  NaN
# 0             Zimbabwe       [E Chigumbura]
# ..                 ...                  ...
# 0             Pakistan         [Umar Akmal]
# 0                India           [S Dhawan]
# 0          Netherlands   [Mudassar Bukhari]
# 0            Australia         [GJ Maxwell]
# 0            Australia         [GJ Maxwell]
#
#                              info.teams info.toss.decision  \
# 0                [Australia, Sri Lanka]              field
# 0                [Australia, Sri Lanka]              field
# 0                [Australia, Sri Lanka]              field
# 0                  [Ireland, Hong Kong]                bat
# 0                     [Zimbabwe, India]              field
# ..                                  ...                ...
# 0                 [Pakistan, Sri Lanka]              field
# 0                   [Bangladesh, India]              field
# 0   [United Arab Emirates, Netherlands]              field
# 0                [Sri Lanka, Australia]              field
# 0                [Sri Lanka, Australia]                bat
#
#         info.toss.winner                        info.umpires  \
# 0              Sri Lanka              [MD Martell, P Wilson]
# 0              Sri Lanka               [SD Fry, SJ Nogajski]
# 0              Sri Lanka              [MD Martell, P Wilson]
# 0              Hong Kong                 [R Black, AJ Neill]
# 0                  India            [TJ Matibiri, RB Tiffin]
# ..                   ...                                 ...
# 0               Pakistan        [AK Chaudhary, Enamul Haque]
# 0                  India    [RSA Palliyaguruge, Shozab Raza]
# 0   United Arab Emirates          [CK Nandan, Sarika Prasad]
# 0              Sri Lanka      [REJ Martinesz, RR Wimalasiri]
# 0              Sri Lanka  [REJ Martinesz, RSA Palliyaguruge]
#
#                                  info.venue  match_id    info.city
# 0                  Melbourne Cricket Ground         1          NaN
# 0            Simonds Stadium, South Geelong         2     Victoria
# 0                             Adelaide Oval         3          NaN
# 0         Bready Cricket Club, Magheramason         4  Londonderry
# 0                        Harare Sports Club         5          NaN
# ..                                      ...       ...          ...
# 0             Shere Bangla National Stadium      1428       Mirpur
# 0             Shere Bangla National Stadium      1429       Mirpur
# 0                               ICC Academy      1430        Dubai
# 0   Pallekele International Cricket Stadium      1431          NaN
# 0                       R Premadasa Stadium      1432      Colombo
#
# [963 rows x 11 columns]

# %%
import pickle
# pickle.dump(final_df,open ('dataset_level1.pk1','wb'))

# %%
matches = pickle.load(open('dataset_level1.pk1','rb'))
matches.head(128)
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...  [2018-07-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2018-07-06]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2018-07-08]
# 0   [{'1st innings': {'team': 'South Africa', 'del...  [2018-10-09]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2018-10-12]
#
#    info.outcome.winner info.player_of_match                info.teams  \
# 0            Sri Lanka      [DAS Gunaratne]    [Australia, Sri Lanka]
# 0            Sri Lanka      [DAS Gunaratne]    [Australia, Sri Lanka]
# 0            Australia            [A Zampa]    [Australia, Sri Lanka]
# 0            Hong Kong                  NaN      [Ireland, Hong Kong]
# 0             Zimbabwe       [E Chigumbura]         [Zimbabwe, India]
# ..                 ...                  ...                       ...
# 0             Pakistan       [Fakhar Zaman]     [Pakistan, Australia]
# 0            Australia             [AJ Tye]     [Zimbabwe, Australia]
# 0             Pakistan       [Fakhar Zaman]     [Australia, Pakistan]
# 0         South Africa        [Imran Tahir]  [South Africa, Zimbabwe]
# 0         South Africa         [D Paterson]  [Zimbabwe, South Africa]
#
#    info.toss.decision info.toss.winner              info.umpires  \
# 0               field        Sri Lanka    [MD Martell, P Wilson]
# 0               field        Sri Lanka     [SD Fry, SJ Nogajski]
# 0               field        Sri Lanka    [MD Martell, P Wilson]
# 0                 bat        Hong Kong       [R Black, AJ Neill]
# 0               field            India  [TJ Matibiri, RB Tiffin]
# ..                ...              ...                       ...
# 0               field        Australia     [RB Tiffin, L Rusere]
# 0                 bat         Zimbabwe  [RB Tiffin, TJ Matibiri]
# 0                 bat        Australia     [RB Tiffin, L Rusere]
# 0                 bat     South Africa  [AT Holdstock, S George]
# 0                 bat         Zimbabwe     [A Paleker, S George]
#
#                            info.venue  match_id      info.city
# 0            Melbourne Cricket Ground         1            NaN
# 0      Simonds Stadium, South Geelong         2       Victoria
# 0                       Adelaide Oval         3            NaN
# 0   Bready Cricket Club, Magheramason         4    Londonderry
# 0                  Harare Sports Club         5            NaN
# ..                                ...       ...            ...
# 0                  Harare Sports Club       162            NaN
# 0                  Harare Sports Club       163            NaN
# 0                  Harare Sports Club       164            NaN
# 0                        Buffalo Park       165    East London
# 0                         Senwes Park       166  Potchefstroom
#
# [128 rows x 11 columns]

# %%
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.4: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {0.5: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.6: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {1.1: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.2: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {1.3: {'batsman': 'AJ Finch',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.4: {'batsman': 'AJ Finch',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.5: {'batsman': 'AJ Finch',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {1.6: {'batsman': 'AJ Finch',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {2.1: {'batsman': 'M Klinger',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.2: {'batsman': 'AJ Finch',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.3: {'batsman': 'M Klinger',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.4: {'batsman': 'M Klinger',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.5: {'batsman': 'M Klinger',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {2.6: {'batsman': 'M Klinger',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.1: {'batsman': 'AJ Finch',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.2: {'batsman': 'AJ Finch',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.3: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.4: {'batsman': 'AJ Finch',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.5: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {3.6: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.1: {'batsman': 'M Klinger',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {4.2: {'batsman': 'AJ Finch',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {4.3: {'batsman': 'M Klinger',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {4.4: {'batsman': 'M Klinger',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {4.5: {'batsman': 'M Klinger',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.6: {'batsman': 'AJ Finch',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.1: {'batsman': 'AJ Finch',
#    'bowler': 'S Prasanna',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.2: {'batsman': 'M Klinger',
#    'bowler': 'S Prasanna',
#    'extras': {'wides': 1},
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {5.3: {'batsman': 'M Klinger',
#    'bowler': 'S Prasanna',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.4: {'batsman': 'M Klinger',
#    'bowler': 'S Prasanna',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.5: {'batsman': 'M Klinger',
#    'bowler': 'S Prasanna',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.6: {'batsman': 'AJ Finch',
#    'bowler': 'S Prasanna',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.7: {'batsman': 'M Klinger',
#    'bowler': 'S Prasanna',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.1: {'batsman': 'AJ Finch',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.2: {'batsman': 'M Klinger',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.3: {'batsman': 'AJ Finch',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.4: {'batsman': 'AJ Finch',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.5: {'batsman': 'M Klinger',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.6: {'batsman': 'AJ Finch',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {7.1: {'batsman': 'M Klinger',
#    'bowler': 'S Prasanna',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.2: {'batsman': 'M Klinger',
#    'bowler': 'S Prasanna',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.3: {'batsman': 'AJ Finch',
#    'bowler': 'S Prasanna',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.4: {'batsman': 'M Klinger',
#    'bowler': 'S Prasanna',
#    'extras': {'byes': 1},
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {7.5: {'batsman': 'AJ Finch',
#    'bowler': 'S Prasanna',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {7.6: {'batsman': 'AJ Finch',
#    'bowler': 'S Prasanna',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.1: {'batsman': 'AJ Finch',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.2: {'batsman': 'M Klinger',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {8.3: {'batsman': 'AJ Finch',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.4: {'batsman': 'M Klinger',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.5: {'batsman': 'M Klinger',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.6: {'batsman': 'M Klinger',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.1: {'batsman': 'M Klinger',
#    'bowler': 'S Prasanna',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.2: {'batsman': 'AJ Finch',
#    'bowler': 'S Prasanna',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.3: {'batsman': 'AJ Finch',
#    'bowler': 'S Prasanna',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.4: {'batsman': 'AJ Finch',
#    'bowler': 'S Prasanna',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.5: {'batsman': 'AJ Finch',
#    'bowler': 'S Prasanna',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {9.6: {'batsman': 'AJ Finch',
#    'bowler': 'S Prasanna',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.1: {'batsman': 'AJ Finch',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.2: {'batsman': 'AJ Finch',
#    'bowler': 'PADLR Sandakan',
#    'extras': {'legbyes': 1},
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {10.3: {'batsman': 'M Klinger',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['SL Malinga'],
#     'kind': 'caught',
#     'player_out': 'M Klinger'}}},
#  {10.4: {'batsman': 'TM Head',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {10.5: {'batsman': 'TM Head',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.6: {'batsman': 'TM Head',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.1: {'batsman': 'AJ Finch',
#    'bowler': 'DAS Gunaratne',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {11.2: {'batsman': 'AJ Finch',
#    'bowler': 'DAS Gunaratne',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {11.3: {'batsman': 'AJ Finch',
#    'bowler': 'DAS Gunaratne',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['SL Malinga'],
#     'kind': 'caught',
#     'player_out': 'AJ Finch'}}},
#  {11.4: {'batsman': 'TM Head',
#    'bowler': 'DAS Gunaratne',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.5: {'batsman': 'MC Henriques',
#    'bowler': 'DAS Gunaratne',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.6: {'batsman': 'TM Head',
#    'bowler': 'DAS Gunaratne',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.1: {'batsman': 'TM Head',
#    'bowler': 'S Prasanna',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.2: {'batsman': 'TM Head',
#    'bowler': 'S Prasanna',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.3: {'batsman': 'MC Henriques',
#    'bowler': 'S Prasanna',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.4: {'batsman': 'TM Head',
#    'bowler': 'S Prasanna',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.5: {'batsman': 'TM Head',
#    'bowler': 'S Prasanna',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.6: {'batsman': 'MC Henriques',
#    'bowler': 'S Prasanna',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.1: {'batsman': 'MC Henriques',
#    'bowler': 'SL Malinga',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.2: {'batsman': 'MC Henriques',
#    'bowler': 'SL Malinga',
#    'extras': {'wides': 1},
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {13.3: {'batsman': 'MC Henriques',
#    'bowler': 'SL Malinga',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.4: {'batsman': 'TM Head',
#    'bowler': 'SL Malinga',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {13.5: {'batsman': 'TM Head',
#    'bowler': 'SL Malinga',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.6: {'batsman': 'MC Henriques',
#    'bowler': 'SL Malinga',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.7: {'batsman': 'TM Head',
#    'bowler': 'SL Malinga',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.1: {'batsman': 'TM Head',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.2: {'batsman': 'MC Henriques',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {14.3: {'batsman': 'TM Head',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.4: {'batsman': 'MC Henriques',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {14.5: {'batsman': 'MC Henriques',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {14.6: {'batsman': 'TM Head',
#    'bowler': 'PADLR Sandakan',
#    'non_striker': 'MC Henriques',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {15.1: {'batsman': 'MC Henriques',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['CK Kapugedera'],
#     'kind': 'caught',
#     'player_out': 'MC Henriques'}}},
#  {15.2: {'batsman': 'TM Head',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Turner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.3: {'batsman': 'AJ Turner',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {15.4: {'batsman': 'AJ Turner',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.5: {'batsman': 'TM Head',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Turner',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {15.6: {'batsman': 'TM Head',
#    'bowler': 'JRMVB Sanjaya',
#    'extras': {'wides': 1},
#    'non_striker': 'AJ Turner',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {15.7: {'batsman': 'TM Head',
#    'bowler': 'JRMVB Sanjaya',
#    'non_striker': 'AJ Turner',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {16.1: {'batsman': 'AJ Turner',
#    'bowler': 'SL Malinga',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {16.2: {'batsman': 'AJ Turner',
#    'bowler': 'SL Malinga',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {16.3: {'batsman': 'AJ Turner',
#    'bowler': 'SL Malinga',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.4: {'batsman': 'TM Head',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Turner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.5: {'batsman': 'AJ Turner',
#    'bowler': 'SL Malinga',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.6: {'batsman': 'TM Head',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Turner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.1: {'batsman': 'TM Head',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'AJ Turner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.2: {'batsman': 'AJ Turner',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {17.3: {'batsman': 'AJ Turner',
#    'bowler': 'KMDN Kulasekara',
#    'extras': {'noballs': 1},
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {17.4: {'batsman': 'AJ Turner',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.5: {'batsman': 'TM Head',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'AJ Turner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.6: {'batsman': 'AJ Turner',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.7: {'batsman': 'TM Head',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'AJ Turner',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {18.1: {'batsman': 'AJ Turner',
#    'bowler': 'SL Malinga',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {18.2: {'batsman': 'AJ Turner',
#    'bowler': 'SL Malinga',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.3: {'batsman': 'TM Head',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Turner',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {18.4: {'batsman': 'TM Head',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Turner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['S Prasanna'],
#     'kind': 'caught',
#     'player_out': 'TM Head'}}},
#  {18.5: {'batsman': 'AJ Turner',
#    'bowler': 'SL Malinga',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['S Prasanna'],
#     'kind': 'caught',
#     'player_out': 'AJ Turner'}}},
#  {18.6: {'batsman': 'JP Faulkner',
#    'bowler': 'SL Malinga',
#    'non_striker': 'TD Paine',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.1: {'batsman': 'JP Faulkner',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'TD Paine',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {19.2: {'batsman': 'JP Faulkner',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'TD Paine',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {19.3: {'batsman': 'JP Faulkner',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'TD Paine',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {19.4: {'batsman': 'JP Faulkner',
#    'bowler': 'KMDN Kulasekara',
#    'extras': {'wides': 1},
#    'non_striker': 'TD Paine',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {19.5: {'batsman': 'JP Faulkner',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'TD Paine',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1},
#    'wicket': {'fielders': ['CK Kapugedera', 'KMDN Kulasekara'],
#     'kind': 'run out',
#     'player_out': 'TD Paine'}}},
#  {19.6: {'batsman': 'JP Faulkner',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {19.7: {'batsman': 'JP Faulkner',
#    'bowler': 'KMDN Kulasekara',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}]

# %%
len(matches.iloc[0]['innings'][0]['1st innings']['deliveries'])
# Out:
# 125

# %%
count =1
delivery_df = pd.DataFrame()
for index,row in matches.iterrows():
    print('index',index,'row',row)
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345] :
        count+=1
        continue
    count+=1
    ball_of_match =[]
    batsman =[]
    bowler = []
    runs = []
    player_of_dismissed =[]
    teams = []
    batting_team = []
    match_id =[]
    city = []
    venue = []
    for ball in row ['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except :
                player_of_dismissed.append('0')
                
                
    loop_df = pd.DataFrame({
        'match_id' : match_id,
        'teams' : teams,
        'batting_team' :  batting_team,
        'ball' : ball_of_match,
        'batsman': batsman,
        'bowler' : bowler,
        'runs': runs,
        'player_dismissed' : player_of_dismissed,
        'city' : city,
        'venue' : venue
        
    })
    
    delivery_df = delivery_df.append(loop_df)
# Out:
# index 0 row innings                 [{'1st innings': {'team': 'Australia', 'delive...
# info.dates                                                   [2017-02-17]
# info.outcome.winner                                             Sri Lanka
# info.player_of_match                                      [DAS Gunaratne]
# info.teams                                         [Australia, Sri Lanka]
# info.toss.decision                                                  field
# info.toss.winner                                                Sri Lanka
# info.umpires                                       [MD Martell, P Wilson]
# info.venue                                       Melbourne Cricket Ground
# match_id                                                                1
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Australia', 'delive...
# info.dates                                                   [2017-02-19]
# info.outcome.winner                                             Sri Lanka
# info.player_of_match                                      [DAS Gunaratne]
# info.teams                                         [Australia, Sri Lanka]
# info.toss.decision                                                  field
# info.toss.winner                                                Sri Lanka
# info.umpires                                        [SD Fry, SJ Nogajski]
# info.venue                                 Simonds Stadium, South Geelong
# match_id                                                                2
# info.city                                                        Victoria
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Australia', 'delive...
# info.dates                                                   [2017-02-22]
# info.outcome.winner                                             Australia
# info.player_of_match                                            [A Zampa]
# info.teams                                         [Australia, Sri Lanka]
# info.toss.decision                                                  field
# info.toss.winner                                                Sri Lanka
# info.umpires                                       [MD Martell, P Wilson]
# info.venue                                                  Adelaide Oval
# match_id                                                                3
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Hong Kong', 'delive...
# info.dates                                                   [2016-09-05]
# info.outcome.winner                                             Hong Kong
# info.player_of_match                                                  NaN
# info.teams                                           [Ireland, Hong Kong]
# info.toss.decision                                                    bat
# info.toss.winner                                                Hong Kong
# info.umpires                                          [R Black, AJ Neill]
# info.venue                              Bready Cricket Club, Magheramason
# match_id                                                                4
# info.city                                                     Londonderry
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Zimbabwe', 'deliver...
# info.dates                                                   [2016-06-18]
# info.outcome.winner                                              Zimbabwe
# info.player_of_match                                       [E Chigumbura]
# info.teams                                              [Zimbabwe, India]
# info.toss.decision                                                  field
# info.toss.winner                                                    India
# info.umpires                                     [TJ Matibiri, RB Tiffin]
# info.venue                                             Harare Sports Club
# match_id                                                                5
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Zimbabwe', 'deliver...
# info.dates                                                   [2016-06-20]
# info.outcome.winner                                                 India
# info.player_of_match                                            [BB Sran]
# info.teams                                              [Zimbabwe, India]
# info.toss.decision                                                    bat
# info.toss.winner                                                 Zimbabwe
# info.umpires                                        [L Rusere, RB Tiffin]
# info.venue                                             Harare Sports Club
# match_id                                                                6
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'India', 'deliveries...
# info.dates                                                   [2016-06-22]
# info.outcome.winner                                                 India
# info.player_of_match                                          [KM Jadhav]
# info.teams                                              [Zimbabwe, India]
# info.toss.decision                                                  field
# info.toss.winner                                                 Zimbabwe
# info.umpires                                     [TJ Matibiri, RB Tiffin]
# info.venue                                             Harare Sports Club
# match_id                                                                7
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Bangladesh', 'deliv...
# info.dates                                                   [2017-01-03]
# info.outcome.winner                                           New Zealand
# info.player_of_match                                      [KS Williamson]
# info.teams                                      [New Zealand, Bangladesh]
# info.toss.decision                                                    bat
# info.toss.winner                                               Bangladesh
# info.umpires                                        [SB Haig, WR Knights]
# info.venue                                                    McLean Park
# match_id                                                                8
# info.city                                                          Napier
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'New Zealand', 'deli...
# info.dates                                                   [2017-01-06]
# info.outcome.winner                                           New Zealand
# info.player_of_match                                            [C Munro]
# info.teams                                      [New Zealand, Bangladesh]
# info.toss.decision                                                  field
# info.toss.winner                                               Bangladesh
# info.umpires                                          [CM Brown, SB Haig]
# info.venue                                                       Bay Oval
# match_id                                                                9
# info.city                                                 Mount Maunganui
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'New Zealand', 'deli...
# info.dates                                                   [2017-01-08]
# info.outcome.winner                                           New Zealand
# info.player_of_match                                        [CJ Anderson]
# info.teams                                      [New Zealand, Bangladesh]
# info.toss.decision                                                  field
# info.toss.winner                                               Bangladesh
# info.umpires                                       [CM Brown, WR Knights]
# info.venue                                                       Bay Oval
# match_id                                                               10
# info.city                                                 Mount Maunganui
# Name: 0, dtype: object
# index 0 row
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# innings                 [{'1st innings': {'team': 'South Africa', 'del...
# info.dates                                                   [2017-02-17]
# info.outcome.winner                                          South Africa
# info.player_of_match                                        [Imran Tahir]
# info.teams                                    [New Zealand, South Africa]
# info.toss.decision                                                  field
# info.toss.winner                                              New Zealand
# info.umpires                                       [CM Brown, WR Knights]
# info.venue                                                      Eden Park
# match_id                                                               11
# info.city                                                        Auckland
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'South Africa', 'del...
# info.dates                                                   [2017-06-21]
# info.outcome.winner                                               England
# info.player_of_match                                        [JM Bairstow]
# info.teams                                        [England, South Africa]
# info.toss.decision                                                    bat
# info.toss.winner                                             South Africa
# info.umpires                                     [RJ Bailey, RT Robinson]
# info.venue                                                  The Rose Bowl
# match_id                                                               12
# info.city                                                     Southampton
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'South Africa', 'del...
# info.dates                                                   [2017-06-23]
# info.outcome.winner                                          South Africa
# info.player_of_match                                          [CH Morris]
# info.teams                                        [England, South Africa]
# info.toss.decision                                                  field
# info.toss.winner                                                  England
# info.umpires                                        [RJ Bailey, MA Gough]
# info.venue                                                  County Ground
# match_id                                                               13
# info.city                                                         Taunton
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'England', 'deliveri...
# info.dates                                                   [2017-06-25]
# info.outcome.winner                                               England
# info.player_of_match                                           [DJ Malan]
# info.teams                                        [England, South Africa]
# info.toss.decision                                                  field
# info.toss.winner                                             South Africa
# info.umpires                                      [MA Gough, RT Robinson]
# info.venue                                                 Sophia Gardens
# match_id                                                               14
# info.city                                                         Cardiff
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'West Indies', 'deli...
# info.dates                                                   [2017-09-16]
# info.outcome.winner                                           West Indies
# info.player_of_match                                          [SP Narine]
# info.teams                                         [West Indies, England]
# info.toss.decision                                                  field
# info.toss.winner                                                  England
# info.umpires                                      [RT Robinson, MA Gough]
# info.venue                                               Riverside Ground
# match_id                                                               15
# info.city                                               Chester-le-Street
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'India', 'deliveries...
# info.dates                                                   [2017-01-26]
# info.outcome.winner                                               England
# info.player_of_match                                             [MM Ali]
# info.teams                                               [India, England]
# info.toss.decision                                                  field
# info.toss.winner                                                  England
# info.umpires                                  [AK Chaudhary, Nitin Menon]
# info.venue                                                     Green Park
# match_id                                                               16
# info.city                                                          Kanpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'India', 'deliveries...
# info.dates                                                   [2017-01-29]
# info.outcome.winner                                                 India
# info.player_of_match                                          [JJ Bumrah]
# info.teams                                               [India, England]
# info.toss.decision                                                  field
# info.toss.winner                                                  England
# info.umpires                                [AK Chaudhary, C Shamshuddin]
# info.venue                   Vidarbha Cricket Association Stadium, Jamtha
# match_id                                                               17
# info.city                                                          Nagpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'India', 'deliveries...
# info.dates                                                   [2017-02-01]
# info.outcome.winner                                                 India
# info.player_of_match                                          [YS Chahal]
# info.teams                                               [India, England]
# info.toss.decision                                                  field
# info.toss.winner                                                  England
# info.umpires                                  [AK Chaudhary, Nitin Menon]
# info.venue                                          M Chinnaswamy Stadium
# match_id                                                               18
# info.city                                                       Bangalore
# Name: 0, dtype: object
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# index 0 row innings                 [{'1st innings': {'team': 'Ireland', 'deliveri...
# info.dates                                                   [2017-03-08]
# info.outcome.winner                                           Afghanistan
# info.player_of_match                                 [Samiullah Shenwari]
# info.teams                                         [Afghanistan, Ireland]
# info.toss.decision                                                    bat
# info.toss.winner                                                  Ireland
# info.umpires                     [Ahmed Shah Durrani, Ahmed Shah Pakteen]
# info.venue                            Greater Noida Sports Complex Ground
# match_id                                                               19
# info.city                                                   Greater Noida
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Afghanistan', 'deli...
# info.dates                                                   [2017-03-10]
# info.outcome.winner                                           Afghanistan
# info.player_of_match                        [Najeeb Tarakai, Rashid Khan]
# info.teams                                         [Afghanistan, Ireland]
# info.toss.decision                                                    bat
# info.toss.winner                                              Afghanistan
# info.umpires                     [Ahmed Shah Durrani, Ahmed Shah Pakteen]
# info.venue                            Greater Noida Sports Complex Ground
# match_id                                                               20
# info.city                                                   Greater Noida
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Afghanistan', 'deli...
# info.dates                                                   [2017-03-12]
# info.outcome.winner                                           Afghanistan
# info.player_of_match                                      [Mohammad Nabi]
# info.teams                                         [Afghanistan, Ireland]
# info.toss.decision                                                  field
# info.toss.winner                                                  Ireland
# info.umpires                     [Ahmed Shah Durrani, Ahmed Shah Pakteen]
# info.venue                            Greater Noida Sports Complex Ground
# match_id                                                               21
# info.city                                                   Greater Noida
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'West Indies', 'deli...
# info.dates                                                   [2016-08-27]
# info.outcome.winner                                           West Indies
# info.player_of_match                                            [E Lewis]
# info.teams                                           [India, West Indies]
# info.toss.decision                                                  field
# info.toss.winner                                                    India
# info.umpires                                        [N Duguid, JS Wilson]
# info.venue              Central Broward Regional Park Stadium Turf Ground
# match_id                                                               22
# info.city                                                      Lauderhill
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'West Indies', 'deli...
# info.dates                                                   [2016-08-28]
# info.outcome.winner                                                   NaN
# info.player_of_match                                                  NaN
# info.teams                                           [India, West Indies]
# info.toss.decision                                                  field
# info.toss.winner                                                    India
# info.umpires                                       [LS Reifer, JS Wilson]
# info.venue              Central Broward Regional Park Stadium Turf Ground
# match_id                                                               23
# info.city                                                      Lauderhill
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'West Indies', 'deli...
# info.dates                                                   [2016-09-23]
# info.outcome.winner                                              Pakistan
# info.player_of_match                                         [Imad Wasim]
# info.teams                                        [Pakistan, West Indies]
# info.toss.decision                                                  field
# info.toss.winner                                                 Pakistan
# info.umpires                                    [Ahsan Raza, Shozab Raza]
# info.venue                            Dubai International Cricket Stadium
# match_id                                                               28
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Pakistan', 'deliver...
# info.dates                                                   [2016-09-24]
# info.outcome.winner                                              Pakistan
# info.player_of_match                                      [Sarfraz Ahmed]
# info.teams                                        [Pakistan, West Indies]
# info.toss.decision                                                  field
# info.toss.winner                                              West Indies
# info.umpires                                  [Ahmed Shahab, Shozab Raza]
# info.venue                            Dubai International Cricket Stadium
# match_id                                                               29
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'West Indies', 'deli...
# info.dates                                                   [2016-09-27]
# info.outcome.winner                                              Pakistan
# info.player_of_match                                         [Imad Wasim]
# info.teams                                        [Pakistan, West Indies]
# info.toss.decision                                                  field
# info.toss.winner                                                 Pakistan
# info.umpires                                    [Ahsan Raza, Shozab Raza]
# info.venue                                           Sheikh Zayed Stadium
# match_id                                                               30
# info.city                                                       Abu Dhabi
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Afghanistan', 'deli...
# info.dates                                                   [2016-12-14]
# info.outcome.winner                                           Afghanistan
# info.player_of_match                                        [Karim Janat]
# info.teams                            [United Arab Emirates, Afghanistan]
# info.toss.decision                                                    bat
# info.toss.winner                                              Afghanistan
# info.umpires                           [Ahmed Shah Durrani, Iftikhar Ali]
# info.venue                                                    ICC Academy
# match_id                                                               33
# info.city                                                           Dubai
# Name: 0, dtype: object
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# index 0 row innings                 [{'1st innings': {'team': 'United Arab Emirate...
# info.dates                                                   [2016-12-16]
# info.outcome.winner                                           Afghanistan
# info.player_of_match                                  [Najibullah Zadran]
# info.teams                            [United Arab Emirates, Afghanistan]
# info.toss.decision                                                    bat
# info.toss.winner                                     United Arab Emirates
# info.umpires                              [Ahmed Shah Durrani, Akbar Ali]
# info.venue                            Dubai International Cricket Stadium
# match_id                                                               34
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Afghanistan', 'deli...
# info.dates                                                   [2016-12-18]
# info.outcome.winner                                           Afghanistan
# info.player_of_match                                        [Rashid Khan]
# info.teams                            [United Arab Emirates, Afghanistan]
# info.toss.decision                                                    bat
# info.toss.winner                                              Afghanistan
# info.umpires                                    [Akbar Ali, Iftikhar Ali]
# info.venue                                                    ICC Academy
# match_id                                                               35
# info.city                                                           Dubai
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'New Zealand', 'deli...
# info.dates                                                   [2018-02-03]
# info.outcome.winner                                             Australia
# info.player_of_match                                         [B Stanlake]
# info.teams                                       [New Zealand, Australia]
# info.toss.decision                                                  field
# info.toss.winner                                                Australia
# info.umpires                                           [CM Brown, SD Fry]
# info.venue                                          Sydney Cricket Ground
# match_id                                                               36
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'England', 'deliveri...
# info.dates                                                   [2018-02-07]
# info.outcome.winner                                             Australia
# info.player_of_match                                         [GJ Maxwell]
# info.teams                                           [England, Australia]
# info.toss.decision                                                  field
# info.toss.winner                                                Australia
# info.umpires                                           [GA Abood, SD Fry]
# info.venue                                                 Bellerive Oval
# match_id                                                               37
# info.city                                                          Hobart
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'England', 'deliveri...
# info.dates                                                   [2018-02-10]
# info.outcome.winner                                             Australia
# info.player_of_match                                      [KW Richardson]
# info.teams                                           [England, Australia]
# info.toss.decision                                                  field
# info.toss.winner                                                Australia
# info.umpires                                      [CM Brown, SJ Nogajski]
# info.venue                                       Melbourne Cricket Ground
# match_id                                                               38
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'New Zealand', 'deli...
# info.dates                                                   [2018-02-13]
# info.outcome.winner                                           New Zealand
# info.player_of_match                                      [KS Williamson]
# info.teams                                         [New Zealand, England]
# info.toss.decision                                                  field
# info.toss.winner                                                  England
# info.umpires                                        [SB Haig, WR Knights]
# info.venue                                                Westpac Stadium
# match_id                                                               39
# info.city                                                      Wellington
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'New Zealand', 'deli...
# info.dates                                                   [2018-02-16]
# info.outcome.winner                                             Australia
# info.player_of_match                                          [DJM Short]
# info.teams                                       [New Zealand, Australia]
# info.toss.decision                                                    bat
# info.toss.winner                                              New Zealand
# info.umpires                                          [P Wilson, SB Haig]
# info.venue                                                      Eden Park
# match_id                                                               40
# info.city                                                        Auckland
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'England', 'deliveri...
# info.dates                                                   [2018-02-18]
# info.outcome.winner                                               England
# info.player_of_match                                         [EJG Morgan]
# info.teams                                         [England, New Zealand]
# info.toss.decision                                                  field
# info.toss.winner                                              New Zealand
# info.umpires                                         [CM Brown, P Wilson]
# info.venue                                                    Seddon Park
# match_id                                                               41
# info.city                                                        Hamilton
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'New Zealand', 'deli...
# info.dates                                                   [2018-02-21]
# info.outcome.winner                                             Australia
# info.player_of_match                                            [AC Agar]
# info.teams                                       [New Zealand, Australia]
# info.toss.decision                                                    bat
# info.toss.winner                                              New Zealand
# info.umpires                                       [CM Brown, WR Knights]
# info.venue                                                      Eden Park
# match_id                                                               42
# info.city                                                        Auckland
# Name: 0, dtype: object
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# index 0 row innings                 [{'1st innings': {'team': 'Scotland', 'deliver...
# info.dates                                                   [2017-01-14]
# info.outcome.winner                                              Scotland
# info.player_of_match                                         [CS MacLeod]
# info.teams                                          [Hong Kong, Scotland]
# info.toss.decision                                                    bat
# info.toss.winner                                                 Scotland
# info.umpires                               [Ahmed Shah Pakteen, AJ Neill]
# info.venue                                           Sheikh Zayed Stadium
# match_id                                                               43
# info.city                                                       Abu Dhabi
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Ireland', 'deliveri...
# info.dates                                                   [2017-01-14]
# info.outcome.winner                                           Afghanistan
# info.player_of_match                                      [Mohammad Nabi]
# info.teams                                         [Afghanistan, Ireland]
# info.toss.decision                                                    bat
# info.toss.winner                                                  Ireland
# info.umpires                                   [Iftikhar Ali, BB Pradhan]
# info.venue                                           Sheikh Zayed Stadium
# match_id                                                               44
# info.city                                                       Abu Dhabi
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Oman', 'deliveries'...
# info.dates                                                   [2017-01-15]
# info.outcome.winner                                           Netherlands
# info.player_of_match                                         [MJG Rippon]
# info.teams                                            [Netherlands, Oman]
# info.toss.decision                                                    bat
# info.toss.winner                                                     Oman
# info.umpires                                  [AJT Dowdalls, Tabarak Dar]
# info.venue                                           Sheikh Zayed Stadium
# match_id                                                               45
# info.city                                                       Abu Dhabi
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Hong Kong', 'delive...
# info.dates                                                   [2017-01-16]
# info.outcome.winner                                                  Oman
# info.player_of_match                                         [Bilal Khan]
# info.teams                                              [Hong Kong, Oman]
# info.toss.decision                                                  field
# info.toss.winner                                                     Oman
# info.umpires                                     [Iftikhar Ali, AJ Neill]
# info.venue                                           Sheikh Zayed Stadium
# match_id                                                               46
# info.city                                                       Abu Dhabi
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'United Arab Emirate...
# info.dates                                                   [2017-01-16]
# info.outcome.winner                                           Afghanistan
# info.player_of_match                                      [Dawlat Zadran]
# info.teams                            [United Arab Emirates, Afghanistan]
# info.toss.decision                                                  field
# info.toss.winner                                              Afghanistan
# info.umpires                                  [AJT Dowdalls, Tabarak Dar]
# info.venue                                           Sheikh Zayed Stadium
# match_id                                                               47
# info.city                                                       Abu Dhabi
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Scotland', 'deliver...
# info.dates                                                   [2017-01-17]
# info.outcome.winner                                              Scotland
# info.player_of_match                                           [JH Davey]
# info.teams                                        [Netherlands, Scotland]
# info.toss.decision                                                  field
# info.toss.winner                                              Netherlands
# info.umpires                                      [AJ Neill, Tabarak Dar]
# info.venue                                           Sheikh Zayed Stadium
# match_id                                                               48
# info.city                                                       Abu Dhabi
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Ireland', 'deliveri...
# info.dates                                                   [2017-01-18]
# info.outcome.winner                                               Ireland
# info.player_of_match                                          [WB Rankin]
# info.teams                                [United Arab Emirates, Ireland]
# info.toss.decision                                                    bat
# info.toss.winner                                                  Ireland
# info.umpires                             [Ahmed Shah Durrani, BB Pradhan]
# info.venue                            Dubai International Cricket Stadium
# match_id                                                               49
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Hong Kong', 'delive...
# info.dates                                                   [2017-01-18]
# info.outcome.winner                                             Hong Kong
# info.player_of_match                                      [Anshuman Rath]
# info.teams                                       [Hong Kong, Netherlands]
# info.toss.decision                                                    bat
# info.toss.winner                                                Hong Kong
# info.umpires                                     [AJT Dowdalls, AJ Neill]
# info.venue                            Dubai International Cricket Stadium
# match_id                                                               50
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Oman', 'deliveries'...
# info.dates                                                   [2017-01-19]
# info.outcome.winner                                              Scotland
# info.player_of_match                                           [MH Cross]
# info.teams                                               [Oman, Scotland]
# info.toss.decision                                                    bat
# info.toss.winner                                                     Oman
# info.umpires                           [Ahmed Shah Pakteen, Iftikhar Ali]
# info.venue                            Dubai International Cricket Stadium
# match_id                                                               51
# info.city                                                             NaN
# Name: 0, dtype: object
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# ...
# match_id                                                             1418
# info.city                                                          Mirpur
# Name: 0, dtype: object
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# index 0 row innings                 [{'1st innings': {'team': 'India', 'deliveries...
# info.dates                                                   [2016-02-24]
# info.outcome.winner                                                 India
# info.player_of_match                                          [RG Sharma]
# info.teams                                            [Bangladesh, India]
# info.toss.decision                                                  field
# info.toss.winner                                               Bangladesh
# info.umpires                             [RSA Palliyaguruge, Shozab Raza]
# info.venue                                  Shere Bangla National Stadium
# match_id                                                             1419
# info.city                                                          Mirpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Sri Lanka', 'delive...
# info.dates                                                   [2016-02-25]
# info.outcome.winner                                             Sri Lanka
# info.player_of_match                                         [SL Malinga]
# info.teams                              [Sri Lanka, United Arab Emirates]
# info.toss.decision                                                  field
# info.toss.winner                                     United Arab Emirates
# info.umpires                                 [AK Chaudhary, Sharfuddoula]
# info.venue                                  Shere Bangla National Stadium
# match_id                                                             1420
# info.city                                                          Mirpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Bangladesh', 'deliv...
# info.dates                                                   [2016-02-26]
# info.outcome.winner                                            Bangladesh
# info.player_of_match                                        [Mahmudullah]
# info.teams                             [Bangladesh, United Arab Emirates]
# info.toss.decision                                                  field
# info.toss.winner                                     United Arab Emirates
# info.umpires                            [AK Chaudhary, RSA Palliyaguruge]
# info.venue                                  Shere Bangla National Stadium
# match_id                                                             1421
# info.city                                                          Mirpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Pakistan', 'deliver...
# info.dates                                                   [2016-02-27]
# info.outcome.winner                                                 India
# info.player_of_match                                            [V Kohli]
# info.teams                                              [India, Pakistan]
# info.toss.decision                                                  field
# info.toss.winner                                                    India
# info.umpires                            [RSA Palliyaguruge, Sharfuddoula]
# info.venue                                  Shere Bangla National Stadium
# match_id                                                             1422
# info.city                                                          Mirpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Bangladesh', 'deliv...
# info.dates                                                   [2016-02-28]
# info.outcome.winner                                            Bangladesh
# info.player_of_match                                      [Sabbir Rahman]
# info.teams                                        [Bangladesh, Sri Lanka]
# info.toss.decision                                                    bat
# info.toss.winner                                               Bangladesh
# info.umpires                                  [AK Chaudhary, Shozab Raza]
# info.venue                                  Shere Bangla National Stadium
# match_id                                                             1423
# info.city                                                          Mirpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'United Arab Emirate...
# info.dates                                                   [2016-02-29]
# info.outcome.winner                                              Pakistan
# info.player_of_match                                       [Shoaib Malik]
# info.teams                               [Pakistan, United Arab Emirates]
# info.toss.decision                                                    bat
# info.toss.winner                                     United Arab Emirates
# info.umpires                            [Enamul Haque, RSA Palliyaguruge]
# info.venue                                  Shere Bangla National Stadium
# match_id                                                             1424
# info.city                                                          Mirpur
# Name: 0, dtype: object
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# index 0 row innings                 [{'1st innings': {'team': 'Sri Lanka', 'delive...
# info.dates                                                   [2016-03-01]
# info.outcome.winner                                                 India
# info.player_of_match                                            [V Kohli]
# info.teams                                             [India, Sri Lanka]
# info.toss.decision                                                  field
# info.toss.winner                                                    India
# info.umpires                                 [Anisur Rahman, Shozab Raza]
# info.venue                                  Shere Bangla National Stadium
# match_id                                                             1425
# info.city                                                          Mirpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Pakistan', 'deliver...
# info.dates                                                   [2016-03-02]
# info.outcome.winner                                            Bangladesh
# info.player_of_match                                      [Soumya Sarkar]
# info.teams                                         [Bangladesh, Pakistan]
# info.toss.decision                                                    bat
# info.toss.winner                                                 Pakistan
# info.umpires                            [AK Chaudhary, RSA Palliyaguruge]
# info.venue                                  Shere Bangla National Stadium
# match_id                                                             1426
# info.city                                                          Mirpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'United Arab Emirate...
# info.dates                                                   [2016-03-03]
# info.outcome.winner                                                 India
# info.player_of_match                                          [RG Sharma]
# info.teams                                  [India, United Arab Emirates]
# info.toss.decision                                                    bat
# info.toss.winner                                     United Arab Emirates
# info.umpires                                  [Sharfuddoula, Shozab Raza]
# info.venue                                  Shere Bangla National Stadium
# match_id                                                             1427
# info.city                                                          Mirpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Sri Lanka', 'delive...
# info.dates                                                   [2016-03-04]
# info.outcome.winner                                              Pakistan
# info.player_of_match                                         [Umar Akmal]
# info.teams                                          [Pakistan, Sri Lanka]
# info.toss.decision                                                  field
# info.toss.winner                                                 Pakistan
# info.umpires                                 [AK Chaudhary, Enamul Haque]
# info.venue                                  Shere Bangla National Stadium
# match_id                                                             1428
# info.city                                                          Mirpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Bangladesh', 'deliv...
# info.dates                                                   [2016-03-06]
# info.outcome.winner                                                 India
# info.player_of_match                                           [S Dhawan]
# info.teams                                            [Bangladesh, India]
# info.toss.decision                                                  field
# info.toss.winner                                                    India
# info.umpires                             [RSA Palliyaguruge, Shozab Raza]
# info.venue                                  Shere Bangla National Stadium
# match_id                                                             1429
# info.city                                                          Mirpur
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Netherlands', 'deli...
# info.dates                                                   [2016-02-03]
# info.outcome.winner                                           Netherlands
# info.player_of_match                                   [Mudassar Bukhari]
# info.teams                            [United Arab Emirates, Netherlands]
# info.toss.decision                                                  field
# info.toss.winner                                     United Arab Emirates
# info.umpires                                   [CK Nandan, Sarika Prasad]
# info.venue                                                    ICC Academy
# match_id                                                             1430
# info.city                                                           Dubai
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Australia', 'delive...
# info.dates                                                   [2016-09-06]
# info.outcome.winner                                             Australia
# info.player_of_match                                         [GJ Maxwell]
# info.teams                                         [Sri Lanka, Australia]
# info.toss.decision                                                  field
# info.toss.winner                                                Sri Lanka
# info.umpires                               [REJ Martinesz, RR Wimalasiri]
# info.venue                        Pallekele International Cricket Stadium
# match_id                                                             1431
# info.city                                                             NaN
# Name: 0, dtype: object
# index 0 row innings                 [{'1st innings': {'team': 'Sri Lanka', 'delive...
# info.dates                                                   [2016-09-09]
# info.outcome.winner                                             Australia
# info.player_of_match                                         [GJ Maxwell]
# info.teams                                         [Sri Lanka, Australia]
# info.toss.decision                                                    bat
# info.toss.winner                                                Sri Lanka
# info.umpires                           [REJ Martinesz, RSA Palliyaguruge]
# info.venue                                            R Premadasa Stadium
# match_id                                                             1432
# info.city                                                         Colombo
# Name: 0, dtype: object
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\asus\AppData\Local\Temp\ipykernel_11852\3692045068.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)

# %%
delivery_df['batting_team']
# Out:
# 0      Australia
# 1      Australia
# 2      Australia
# 3      Australia
# 4      Australia
#          ...
# 121    Sri Lanka
# 122    Sri Lanka
# 123    Sri Lanka
# 124    Sri Lanka
# 125    Sri Lanka
# Name: batting_team, Length: 115325, dtype: object

# %%
def bowl (row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team']=delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0           2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1           2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2           2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3           2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4           2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121       964  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122       964  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123       964  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124       964  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125       964  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue  \
# 0    SL Malinga     0                0      NaN  Melbourne Cricket Ground
# 1    SL Malinga     0                0      NaN  Melbourne Cricket Ground
# 2    SL Malinga     1                0      NaN  Melbourne Cricket Ground
# 3    SL Malinga     2                0      NaN  Melbourne Cricket Ground
# 4    SL Malinga     0                0      NaN  Melbourne Cricket Ground
# ..          ...   ...              ...      ...                       ...
# 121    MA Starc     1                0  Colombo       R Premadasa Stadium
# 122    MA Starc     0                0  Colombo       R Premadasa Stadium
# 123    MA Starc     0      DM de Silva  Colombo       R Premadasa Stadium
# 124    MA Starc     2                0  Colombo       R Premadasa Stadium
# 125    MA Starc     1                0  Colombo       R Premadasa Stadium
#
#     bowling_team
# 0      Sri Lanka
# 1      Sri Lanka
# 2      Sri Lanka
# 3      Sri Lanka
# 4      Sri Lanka
# ..           ...
# 121    Australia
# 122    Australia
# 123    Australia
# 124    Australia
# 125    Australia
#
# [115325 rows x 11 columns]

# %%
delivery_df.drop(columns =['teams'],inplace = True)

# %%
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# 1                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# 2                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# 3                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# 4                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ..               ...      ...                       ...          ...
# 121                0  Colombo       R Premadasa Stadium    Australia
# 122                0  Colombo       R Premadasa Stadium    Australia
# 123      DM de Silva  Colombo       R Premadasa Stadium    Australia
# 124                0  Colombo       R Premadasa Stadium    Australia
# 125                0  Colombo       R Premadasa Stadium    Australia
#
# [115325 rows x 10 columns]

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Australia', 'Hong Kong', 'Zimbabwe', 'India', 'Bangladesh',
#        'New Zealand', 'South Africa', 'England', 'West Indies', 'Ireland',
#        'Afghanistan', 'Pakistan', 'United Arab Emirates', 'Scotland',
#        'Oman', 'Papua New Guinea', 'Sri Lanka', 'Netherlands', 'Nepal',
#        'Vanuatu', 'Philippines', 'United States of America', 'Germany',
#        'Ghana', 'Uganda', 'Kenya', 'Namibia', 'Nigeria', 'Botswana',
#        'Guernsey', 'Denmark', 'Jersey', 'Italy', 'Norway', 'Thailand',
#        'Malaysia', 'Maldives', 'Singapore', 'Kuwait', 'Bermuda', 'Canada',
#        'Cayman Islands', 'Portugal', 'Gibraltar', 'Spain', 'Bhutan',
#        'Qatar', 'Iran', 'Belgium', 'Isle of Man', 'Bulgaria', 'Romania'],
#       dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# 1                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# 2                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# 3                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# 4                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ..               ...      ...                       ...          ...
# 121                0  Colombo       R Premadasa Stadium    Australia
# 122                0  Colombo       R Premadasa Stadium    Australia
# 123      DM de Silva  Colombo       R Premadasa Stadium    Australia
# 124                0  Colombo       R Premadasa Stadium    Australia
# 125                0  Colombo       R Premadasa Stadium    Australia
#
# [63888 rows x 10 columns]

# %%
output =delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))

# %%
import pickle

# %%
df=pickle.load(open('dataset_level2.pkl','rb'))

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       964    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       964    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# 0    Melbourne Cricket Ground
# 1    Melbourne Cricket Ground
# 2    Melbourne Cricket Ground
# 3    Melbourne Cricket Ground
# 4    Melbourne Cricket Ground
# ..                        ...
# 121       R Premadasa Stadium
# 122       R Premadasa Stadium
# 123       R Premadasa Stadium
# 124       R Premadasa Stadium
# 125       R Premadasa Stadium
#
# [63888 rows x 8 columns]

# %% [markdown]
# # match id
# # batting team
# # bowling_team
# # City
# # Current Runrate
# # ball left
# # wickets left
# # last 5

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
# for city taking first letter from venue
import numpy as np

# %%
df['venue'].str.split().apply(lambda x:x[0])
# Out:
# 0      Melbourne
# 1      Melbourne
# 2      Melbourne
# 3      Melbourne
# 4      Melbourne
#          ...
# 121            R
# 122            R
# 123            R
# 124            R
# 125            R
# Name: venue, Length: 63888, dtype: object

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df['city'].isnull().sum()
# Out:
# 0

# %%
# purpose of the venue has finished
# drop the column

# %%
df.drop(columns=['venue'],inplace = True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [63888 rows x 7 columns]

# %%
df['city'].value_counts()
# Out:
# Colombo          4086
# Mirpur           3420
# Johannesburg     3331
# Dubai            2969
# Auckland         2532
#                  ...
# Nairobi           123
# Potchefstroom     122
# Dharamsala        122
# Ahmedabad         121
# Carrara            64
# Name: city, Length: 86, dtype: int64

# %%
# consider city who have more than 5 matches or more than 600 balls

# %%
df['city'].value_counts()[df['city'].value_counts()>600]
# Out:
# Colombo            4086
# Mirpur             3420
# Johannesburg       3331
# Dubai              2969
# Auckland           2532
# Cape Town          2369
# London             2106
# Pallekele          2066
# Barbados           2050
# Sydney             1579
# Melbourne          1574
# Durban             1520
# St Lucia           1487
# Wellington         1350
# Lauderhill         1238
# Hamilton           1219
# Centurion          1189
# Manchester         1144
# Abu Dhabi          1099
# Mumbai              995
# Nottingham          991
# Southampton         987
# Mount Maunganui     938
# Chittagong          868
# Kolkata             844
# Lahore              748
# Delhi               739
# Nagpur              735
# Chandigarh          627
# Adelaide            623
# Bangalore           620
# St Kitts            618
# Cardiff             615
# Christchurch        614
# Trinidad            611
# Name: city, dtype: int64

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts()>600].index.tolist()

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']

# %%
df= df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [50501 rows x 7 columns]

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\1598928411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# 3    Melbourne              3
# 4    Melbourne              3
# ..         ...            ...
# 121    Colombo            125
# 122    Colombo            125
# 123    Colombo            125
# 124    Colombo            127
# 125    Colombo            128
#
# [50501 rows x 8 columns]

# %%
# ball left ans CRR

# %%
df['over'] = df ['ball'].apply(lambda x:str(x).split('.')[0])
df['ball_no'] = df ['ball'].apply(lambda x:str(x).split('.')[1])
# Out:
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\628956358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df ['ball'].apply(lambda x:str(x).split('.')[0])
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\628956358.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df ['ball'].apply(lambda x:str(x).split('.')[1])

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no
# 0    Melbourne              0    0       1
# 1    Melbourne              0    0       2
# 2    Melbourne              1    0       3
# 3    Melbourne              3    0       4
# 4    Melbourne              3    0       5
# ..         ...            ...  ...     ...
# 121    Colombo            125   19       3
# 122    Colombo            125   19       4
# 123    Colombo            125   19       5
# 124    Colombo            127   19       6
# 125    Colombo            128   19       7
#
# [50501 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6)+df ['ball_no'].astype('int')
# Out:
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\843358994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6)+df ['ball_no'].astype('int')

# %%
df['balls_left']= 120 -df['balls_bowled']
# Out:
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\2940341631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left']= 120 -df['balls_bowled']

# %%
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
# Out:
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\2532840769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
df.columns
# Out:
# Index(['match_id', 'batting_team', 'bowling_team', 'ball', 'runs',
#        'player_dismissed', 'city', 'current_score', 'over', 'ball_no',
#        'balls_bowled', 'balls_left'],
#       dtype='object')

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
# [50501 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\3870627026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\3870627026.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\3870627026.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\3870627026.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left
# 0              10
# 1              10
# 2              10
# 3              10
# 4              10
# ..            ...
# 121             2
# 122             2
# 123             1
# 124             1
# 125             1
#
# [50501 rows x 13 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\914577034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr
# 0              10  0.000000
# 1              10  0.000000
# 2              10  2.000000
# 3              10  4.500000
# 4              10  3.600000
# ..            ...       ...
# 121             2  6.410256
# 122             2  6.355932
# 123             1  6.302521
# 124             1  6.350000
# 125             1  6.347107
#
# [50501 rows x 14 columns]

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\3055083752.py:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr
# 0              10  0.000000
# 1              10  0.000000
# 2              10  2.000000
# 3              10  4.500000
# 4              10  3.600000
# ..            ...       ...
# 121             2  6.410256
# 122             2  6.355932
# 123             1  6.302521
# 124             1  6.350000
# 125             1  6.347107
#
# [50501 rows x 14 columns]

# %%
last_five
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  43.0,
#  44.0,
#  45.0,
#  44.0,
#  42.0,
#  43.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  42.0,
#  39.0,
#  38.0,
#  39.0,
#  38.0,
#  39.0,
#  40.0,
#  37.0,
#  41.0,
#  42.0,
#  42.0,
#  44.0,
#  44.0,
#  40.0,
#  39.0,
#  37.0,
#  35.0,
#  31.0,
#  27.0,
#  26.0,
#  31.0,
#  31.0,
#  30.0,
#  31.0,
#  31.0,
#  32.0,
#  31.0,
#  31.0,
#  36.0,
#  37.0,
#  37.0,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  35.0,
#  32.0,
#  32.0,
#  31.0,
#  29.0,
#  29.0,
#  31.0,
#  32.0,
#  32.0,
#  32.0,
#  33.0,
#  36.0,
#  37.0,
#  37.0,
#  39.0,
#  41.0,
#  40.0,
#  41.0,
#  41.0,
#  42.0,
#  44.0,
#  39.0,
#  43.0,
#  45.0,
#  48.0,
#  48.0,
#  48.0,
#  49.0,
#  49.0,
#  49.0,
#  51.0,
#  51.0,
#  51.0,
#  52.0,
#  52.0,
#  53.0,
#  53.0,
#  53.0,
#  54.0,
#  53.0,
#  52.0,
#  50.0,
#  53.0,
#  47.0,
#  46.0,
#  45.0,
#  46.0,
#  47.0,
#  49.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  46.0,
#  52.0,
#  53.0,
#  57.0,
#  58.0,
#  59.0,
#  59.0,
#  59.0,
#  53.0,
#  53.0,
#  54.0,
#  50.0,
#  50.0,
#  49.0,
#  50.0,
#  47.0,
#  48.0,
#  49.0,
#  49.0,
#  46.0,
#  46.0,
#  51.0,
#  48.0,
#  48.0,
#  48.0,
#  44.0,
#  45.0,
#  42.0,
#  43.0,
#  40.0,
#  39.0,
#  39.0,
#  39.0,
#  36.0,
#  35.0,
#  39.0,
#  39.0,
#  38.0,
#  38.0,
#  37.0,
#  37.0,
#  38.0,
#  39.0,
#  41.0,
#  40.0,
#  40.0,
#  39.0,
#  38.0,
#  39.0,
#  42.0,
#  47.0,
#  42.0,
#  45.0,
#  45.0,
#  49.0,
#  49.0,
#  48.0,
#  47.0,
#  45.0,
#  45.0,
#  45.0,
#  40.0,
#  41.0,
#  41.0,
#  42.0,
#  37.0,
#  38.0,
#  39.0,
#  43.0,
#  46.0,
#  47.0,
#  47.0,
#  46.0,
#  50.0,
#  56.0,
#  57.0,
#  60.0,
#  59.0,
#  59.0,
#  55.0,
#  51.0,
#  51.0,
#  51.0,
#  53.0,
#  51.0,
#  51.0,
#  52.0,
#  53.0,
#  54.0,
#  53.0,
#  54.0,
#  53.0,
#  52.0,
#  51.0,
#  51.0,
#  51.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  42.0,
#  42.0,
#  43.0,
#  42.0,
#  42.0,
#  43.0,
#  40.0,
#  40.0,
#  37.0,
#  33.0,
#  33.0,
#  33.0,
#  34.0,
#  34.0,
#  35.0,
#  36.0,
#  36.0,
#  37.0,
#  34.0,
#  39.0,
#  35.0,
#  36.0,
#  36.0,
#  33.0,
#  33.0,
#  34.0,
#  34.0,
#  35.0,
#  34.0,
#  35.0,
#  41.0,
#  43.0,
#  41.0,
#  42.0,
#  43.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  47.0,
#  50.0,
#  51.0,
#  52.0,
#  57.0,
#  53.0,
#  58.0,
#  61.0,
#  59.0,
#  65.0,
#  68.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  74.0,
#  73.0,
#  68.0,
#  67.0,
#  66.0,
#  66.0,
#  66.0,
#  70.0,
#  70.0,
#  71.0,
#  71.0,
#  72.0,
#  74.0,
#  69.0,
#  65.0,
#  66.0,
#  64.0,
#  59.0,
#  58.0,
#  53.0,
#  50.0,
#  48.0,
#  43.0,
#  40.0,
#  39.0,
#  39.0,
#  39.0,
#  38.0,
#  41.0,
#  42.0,
#  40.0,
#  40.0,
#  41.0,
#  40.0,
#  41.0,
#  40.0,
#  40.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  36.0,
#  36.0,
#  35.0,
#  35.0,
#  32.0,
#  32.0,
#  32.0,
#  31.0,
#  30.0,
#  30.0,
#  30.0,
#  30.0,
#  30.0,
#  31.0,
#  32.0,
#  31.0,
#  31.0,
#  27.0,
#  27.0,
#  27.0,
#  26.0,
#  27.0,
#  28.0,
#  25.0,
#  21.0,
#  20.0,
#  17.0,
#  18.0,
#  18.0,
#  18.0,
#  18.0,
#  19.0,
#  19.0,
#  19.0,
#  20.0,
#  21.0,
#  25.0,
#  26.0,
#  27.0,
#  28.0,
#  34.0,
#  34.0,
#  34.0,
#  35.0,
#  38.0,
#  40.0,
#  44.0,
#  45.0,
#  45.0,
#  45.0,
#  46.0,
#  51.0,
#  54.0,
#  53.0,
#  53.0,
#  53.0,
#  56.0,
#  56.0,
#  59.0,
#  64.0,
#  70.0,
#  70.0,
#  71.0,
#  69.0,
#  67.0,
#  67.0,
#  63.0,
#  62.0,
#  62.0,
#  67.0,
#  67.0,
#  72.0,
#  73.0,
#  71.0,
#  68.0,
#  68.0,
#  65.0,
#  68.0,
#  68.0,
#  74.0,
#  73.0,
#  69.0,
#  66.0,
#  68.0,
#  74.0,
#  74.0,
#  71.0,
#  76.0,
#  73.0,
#  68.0,
#  62.0,
#  67.0,
#  68.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  41.0,
#  42.0,
#  39.0,
#  43.0,
#  44.0,
#  47.0,
#  51.0,
#  51.0,
#  48.0,
#  44.0,
#  44.0,
#  45.0,
#  46.0,
#  47.0,
#  49.0,
#  49.0,
#  50.0,
#  52.0,
#  54.0,
#  54.0,
#  54.0,
#  55.0,
#  54.0,
#  60.0,
#  61.0,
#  56.0,
#  58.0,
#  58.0,
#  54.0,
#  56.0,
#  57.0,
#  56.0,
#  55.0,
#  52.0,
#  51.0,
#  48.0,
#  45.0,
#  46.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  44.0,
#  43.0,
#  43.0,
#  45.0,
#  44.0,
#  47.0,
#  47.0,
#  46.0,
#  49.0,
#  44.0,
#  43.0,
#  46.0,
#  40.0,
#  38.0,
#  44.0,
#  39.0,
#  39.0,
#  40.0,
#  41.0,
#  40.0,
#  46.0,
#  45.0,
#  45.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  47.0,
#  50.0,
#  50.0,
#  50.0,
#  55.0,
#  52.0,
#  51.0,
#  53.0,
#  53.0,
#  53.0,
#  50.0,
#  49.0,
#  50.0,
#  46.0,
#  46.0,
#  50.0,
#  44.0,
#  43.0,
#  44.0,
#  43.0,
#  46.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  33.0,
#  33.0,
#  36.0,
#  36.0,
#  34.0,
#  34.0,
#  35.0,
#  36.0,
#  36.0,
#  36.0,
#  32.0,
#  33.0,
#  32.0,
#  29.0,
#  23.0,
#  23.0,
#  26.0,
#  27.0,
#  27.0,
#  27.0,
#  27.0,
#  26.0,
#  27.0,
#  27.0,
#  27.0,
#  23.0,
#  24.0,
#  25.0,
#  27.0,
#  27.0,
#  28.0,
#  29.0,
#  26.0,
#  27.0,
#  26.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  26.0,
#  27.0,
#  27.0,
#  26.0,
#  28.0,
#  28.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  24.0,
#  25.0,
#  24.0,
#  25.0,
#  25.0,
#  29.0,
#  30.0,
#  29.0,
#  31.0,
#  31.0,
#  31.0,
#  31.0,
#  30.0,
#  29.0,
#  30.0,
#  29.0,
#  34.0,
#  34.0,
#  35.0,
#  35.0,
#  34.0,
#  33.0,
#  38.0,
#  39.0,
#  37.0,
#  38.0,
#  38.0,
#  38.0,
#  37.0,
#  38.0,
#  40.0,
#  43.0,
#  49.0,
#  50.0,
#  51.0,
#  47.0,
#  46.0,
#  52.0,
#  48.0,
#  49.0,
#  49.0,
#  49.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  38.0,
#  39.0,
#  40.0,
#  39.0,
#  39.0,
#  39.0,
#  38.0,
#  42.0,
#  43.0,
#  39.0,
#  38.0,
#  35.0,
#  36.0,
#  36.0,
#  40.0,
#  35.0,
#  38.0,
#  38.0,
#  42.0,
#  41.0,
#  42.0,
#  41.0,
#  41.0,
#  41.0,
#  46.0,
#  43.0,
#  42.0,
#  41.0,
#  43.0,
#  43.0,
#  42.0,
#  41.0,
#  44.0,
#  47.0,
#  48.0,
#  49.0,
#  52.0,
#  49.0,
#  48.0,
#  52.0,
#  53.0,
#  53.0,
#  58.0,
#  58.0,
#  58.0,
#  61.0,
#  58.0,
#  59.0,
#  55.0,
#  57.0,
#  57.0,
#  57.0,
#  61.0,
#  61.0,
#  55.0,
#  58.0,
#  59.0,
#  61.0,
#  56.0,
#  56.0,
#  57.0,
#  58.0,
#  54.0,
#  51.0,
#  54.0,
#  53.0,
#  51.0,
#  52.0,
#  53.0,
#  50.0,
#  49.0,
#  48.0,
#  43.0,
#  48.0,
#  48.0,
#  44.0,
#  43.0,
#  48.0,
#  48.0,
#  45.0,
#  44.0,
#  43.0,
#  41.0,
#  43.0,
#  45.0,
#  47.0,
#  47.0,
#  45.0,
#  45.0,
#  44.0,
#  43.0,
#  42.0,
#  42.0,
#  42.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  37.0,
#  40.0,
#  40.0,
#  41.0,
#  42.0,
#  39.0,
#  39.0,
#  42.0,
#  43.0,
#  44.0,
#  44.0,
#  44.0,
#  42.0,
#  41.0,
#  41.0,
#  41.0,
#  35.0,
#  31.0,
#  30.0,
#  29.0,
#  27.0,
#  27.0,
#  23.0,
#  23.0,
#  24.0,
#  29.0,
#  29.0,
#  28.0,
#  28.0,
#  28.0,
#  29.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  30.0,
#  29.0,
#  29.0,
#  29.0,
#  33.0,
#  33.0,
#  34.0,
#  34.0,
#  35.0,
#  36.0,
#  37.0,
#  41.0,
#  41.0,
#  42.0,
#  46.0,
#  47.0,
#  48.0,
#  47.0,
#  47.0,
#  41.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  41.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  37.0,
#  36.0,
#  37.0,
#  37.0,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  33.0,
#  33.0,
#  38.0,
#  36.0,
#  35.0,
#  34.0,
#  35.0,
#  36.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  35.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
df['last_five']= last_five
# Out:
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\1189887826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five']= last_five

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0             2     168    Australia    Sri Lanka   0.1       0
# 1             2     168    Australia    Sri Lanka   0.2       0
# 2             2     168    Australia    Sri Lanka   0.3       1
# 3             2     168    Australia    Sri Lanka   0.4       2
# 4             2     168    Australia    Sri Lanka   0.5       0
# ...         ...     ...          ...          ...   ...     ...
# 50496       964     128    Sri Lanka    Australia  19.3       1
# 50497       964     128    Sri Lanka    Australia  19.4       0
# 50498       964     128    Sri Lanka    Australia  19.5       0
# 50499       964     128    Sri Lanka    Australia  19.6       2
# 50500       964     128    Sri Lanka    Australia  19.7       1
#
#        player_dismissed       city  current_score over ball_no  balls_bowled  \
# 0                     0  Melbourne              0    0       1             1
# 1                     0  Melbourne              0    0       2             2
# 2                     0  Melbourne              1    0       3             3
# 3                     0  Melbourne              3    0       4             4
# 4                     0  Melbourne              3    0       5             5
# ...                 ...        ...            ...  ...     ...           ...
# 50496                 8    Colombo            125   19       3           117
# 50497                 8    Colombo            125   19       4           118
# 50498                 9    Colombo            125   19       5           119
# 50499                 9    Colombo            127   19       6           120
# 50500                 9    Colombo            128   19       7           121
#
#        balls_left  wickets_left       crr  last_five
# 0             119            10  0.000000        NaN
# 1             118            10  0.000000        NaN
# 2             117            10  2.000000        NaN
# 3             116            10  4.500000        NaN
# 4             115            10  3.600000        NaN
# ...           ...           ...       ...        ...
# 50496           3             2  6.410256       32.0
# 50497           2             2  6.355932       32.0
# 50498           1             1  6.302521       32.0
# 50499           0             1  6.350000       33.0
# 50500           0             1  6.347107       32.0
#
# [50501 rows x 16 columns]

# %%
final_df = final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 50496    Sri Lanka    Australia    Colombo            125           3
# 50497    Sri Lanka    Australia    Colombo            125           2
# 50498    Sri Lanka    Australia    Colombo            125           1
# 50499    Sri Lanka    Australia    Colombo            127           0
# 50500    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# 1                10  0.000000        NaN     168
# 2                10  2.000000        NaN     168
# 3                10  4.500000        NaN     168
# 4                10  3.600000        NaN     168
# ...             ...       ...        ...     ...
# 50496             2  6.410256       32.0     128
# 50497             2  6.355932       32.0     128
# 50498             1  6.302521       32.0     128
# 50499             1  6.350000       33.0     128
# 50500             1  6.347107       32.0     128
#
# [50501 rows x 9 columns]

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12024
# runs_x               0
# dtype: int64

# %%
final_df.dropna(inplace=True)
# Out:
# C:\Users\DL.-Guest\AppData\Local\Temp\ipykernel_1460\2709626079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 29       Australia    Sri Lanka  Melbourne             43          90
# 30       Australia    Sri Lanka  Melbourne             44          89
# 31       Australia    Sri Lanka  Melbourne             45          88
# 32       Australia    Sri Lanka  Melbourne             45          87
# 33       Australia    Sri Lanka  Melbourne             45          86
# ...            ...          ...        ...            ...         ...
# 50496    Sri Lanka    Australia    Colombo            125           3
# 50497    Sri Lanka    Australia    Colombo            125           2
# 50498    Sri Lanka    Australia    Colombo            125           1
# 50499    Sri Lanka    Australia    Colombo            127           0
# 50500    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 29               10  8.600000       43.0     168
# 30               10  8.516129       44.0     168
# 31               10  8.437500       45.0     168
# 32               10  8.181818       44.0     168
# 33               10  7.941176       42.0     168
# ...             ...       ...        ...     ...
# 50496             2  6.410256       32.0     128
# 50497             2  6.355932       32.0     128
# 50498             1  6.302521       32.0     128
# 50499             1  6.350000       33.0     128
# 50500             1  6.347107       32.0     128
#
# [38477 rows x 9 columns]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.columns
# Out:
# Index(['batting_team', 'bowling_team', 'city', 'current_score', 'balls_left',
#        'wickets_left', 'crr', 'last_five', 'runs_x'],
#       dtype='object')

# %%
final_df.sample(2)
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 35121        India      England     Mumbai            153          15
# 50351    Australia    Sri Lanka  Pallekele            199          23
#
#        wickets_left        crr  last_five  runs_x
# 35121             5   8.742857       58.0     177
# 50351             8  12.309278       75.0     263

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 27082     Sri Lanka         India        Nagpur             43          85
# 6014          India    Bangladesh       Colombo             35          91
# 25047   New Zealand      Pakistan      Barbados             99          30
# 46669  South Africa     Sri Lanka     Cape Town             74          65
# 35801   New Zealand       England      Hamilton             75          67
# ...             ...           ...           ...            ...         ...
# 10249         India    Bangladesh         Delhi             92          34
# 42679       England     Australia       Cardiff            128          32
# 6816       Pakistan  South Africa     Centurion            143          16
# 15987   New Zealand     Sri Lanka  Johannesburg            103          42
# 43316       England  South Africa     Cape Town            119          11
#
#        wickets_left       crr  last_five
# 27082            10  7.371429       34.0
# 6014             10  7.241379       35.0
# 25047             5  6.600000       38.0
# 46669             9  8.072727       38.0
# 35801             9  8.490566       42.0
# ...             ...       ...        ...
# 10249             7  6.418605       31.0
# 42679             8  8.727273       68.0
# 6816              4  8.250000       44.0
# 15987             5  7.923077       42.0
# 43316             3  6.550459       37.0
#
# [30781 rows x 8 columns]

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\dl.-guest\anaconda3\lib\site-packages (1.6.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\dl.-guest\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\dl.-guest\anaconda3\lib\site-packages (from xgboost) (1.7.3)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop = 'first'),['batting_team','bowling_team','city'])
]
,remainder = 'passthrough')

# %%
pipe = Pipeline(steps = [
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators = 1000 , learning_rate = 0.2 ,max_depth = 12,random_state =1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9871314473319616
# 1.7123204001270065

# %%
import streamlit as st
import pickle
import pandas as pd

pipe = pickle.load(open('pipe.pkl', 'rb'))

teams = ['Australia',
         'India',
         'Bangladesh',
         'New Zealand',
         'South Africa',
         'England',
         'West Indies',
         'Afghanistan',
         'Pakistan',
         'Sri Lanka']

city = ['Colombo',
        'Mirpur',
        'Johannesburg',
        'Dubai',
        'Auckland',
        'Cape Town',
        'London',
        'Pallekele',
        'Barbados',
        'Sydney',
        'Melbourne',
        'Durban',
        'St Lucia',
        'Wellington',
        'Lauderhill',
        'Hamilton',
        'Centurion',
        'Manchester',
        'Abu Dhabi',
        'Mumbai',
        'Nottingham',
        'Southampton',
        'Mount Maunganui',
        'Chittagong',
        'Kolkata',
        'Lahore',
        'Delhi',
        'Nagpur',
        'Chandigarh',
        'Adelaide',
        'Bangalore',
        'St Kitts',
        'Cardiff',
        'Christchurch',
        'Trinidad']

st.title('Cricket Score Predictor')

col1, col2 = st.columns(2)

with col1:
    batting_team = st.selectbox('Select Batting team', sorted(teams))
with col1:
    bowling_team = st.selectbox('Select Bowling team', sorted(teams))

col3, col4, col5 = st.columns(3)

with col3:
    current_score = st.number_input('Current Score')
with col4:
    overs = st.number_input('overs done (works for >5 over)')
with col5:
    wickets = st.number_input('Wickets Out')

last_five = st.number_input('Runs scored in last 5 overs')
if st.button('Predict Score'):
    balls_left = 120 - (overs * 6)
    wickets_left = 10 - wickets
    crr = current_score / overs

    input_df = pd.DataFrame(
        {'batting_team': [batting_team], 'bowling_team': [bowling_team], 'city': city, 'current_score': [current_score],
         'balls_left': balls_left, 'wickets_left': wickets, 'crr': crr, 'last_five': [last_five]
         })

    result = pipe.predict(input_df)
    st.header('predicted Score' + str(int(result[0])))
# Out:
# 2022-09-03 18:20:01.437
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\DL.-Guest\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
len(input_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 len(input_df)
#
# NameError: name 'input_df' is not defined
